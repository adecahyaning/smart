# %%
pip install flask pytesseract opencv-python numpy pandas tqdm

# %%
pip install fitz
# Out:
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ------------------------- -------------- 2.1/3.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 10.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.6 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.6 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.6 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 11.6 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 11.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ----------------------------- ---------- 2.4/3.2 MB 11.2 MB/s eta 0:00:01
# ...

# %%
import fitz
print(fitz.__doc__)
# Out:
# None
